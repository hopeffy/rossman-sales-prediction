# %% [markdown]
# # Final Pipeline Test
#
# Bu not defteri, `src/` klasöründeki tüm adımları birleştiren `pipeline.py` script'ini çalıştırır. Bu, projenin uçtan uca doğru bir şekilde çalıştığını doğrular.

# %%
import sys
import os

# Projenin kök dizinini path'e ekle
# Bu, 'src' modülünün import edilebilmesi için gereklidir
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.pipeline import run_training_pipeline

# Tüm eğitim pipeline'ını çalıştır
run_training_pipeline()
